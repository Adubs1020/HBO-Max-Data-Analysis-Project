# %%
# !pip install ipython-sql psycopg2

# %%
# %load_ext sql
# Out:
# There's a new jupysql version available (0.10.17), you're running 0.10.12. To upgrade: pip install jupysql --upgrade
# Deploy Streamlit apps for free on Ploomber Cloud! Learn more: https://ploomber.io/s/signup

# %%
# %sql postgresql://postgres:Aces13579@localhost:5433/HBO_TV_Movies
# Out:
# Connecting to 'postgresql://postgres:***@localhost:5433/HBO_TV_Movies'

# %%
# %config SqlMagic.displaylimit = None;
# Out:
# displaylimit: Value None will be treated as 0 (no limit)

# %% [markdown]
# #### Selected all the columns from the credits table in the HBO Max dataset

# %%
# %sql SELECT * FROM Public."Credits" LIMIT 10
# Out:
# Running query in 'postgresql://postgres:***@localhost:5433/HBO_TV_Movies'
# 10 rows affected.
# +-----------+----------+-------------------+-----------------------------------------+-------+
# | person_id |    id    |        name       |                character                |  role |
# +-----------+----------+-------------------+-----------------------------------------+-------+
# |   60017   | tm155702 |    Judy Garland   |               Dorothy Gale              | ACTOR |
# |   53496   | tm155702 |     Ray Bolger    |             Hunk / Scarecrow            | ACTOR |
# |   79549   | tm155702 |     Jack Haley    |            Hickory / Tin Man            | ACTOR |
# |   79548   | tm155702 |     Bert Lahr     |           Zeke / Cowardly Lion          | ACTOR |
# |   60995   | tm155702 | Margaret Hamilton | Elmira Gulch / Wicked Witch of the West | ACTOR |
# |   53493   | tm155702 |    Frank Morgan   |     Professor Marvel / Wizard of Oz     | ACTOR |
# ...

# %% [markdown]
# #### Selected all the columns from the titles table in the  HBO Max dataset

# %%
# %sql Select * FROM Public."Titles" LIMIT 10;
# Out:
# Running query in 'postgresql://postgres:***@localhost:5433/HBO_TV_Movies'
# 10 rows affected.
# +----------+----------------------------------+-------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------+-------------------+---------+---------------------------------------------+----------------------+---------+------------+------------+------------+-----------------+------------+
# ...

# %% [markdown]
# #### Selected the top 10 tv shows by imdb score

# %%
# %%sql SELECT title as tv_show, imdb_score
# FROM Public."Titles"
# WHERE seasons != 'None'
# AND imdb_score IS NOT NULL
# ORDER BY imdb_score DESC
# LIMIT 10;
# Out:
# Running query in 'postgresql://postgres:***@localhost:5433/HBO_TV_Movies'
# 10 rows affected.
# +----------------------------------+------------+
# |             tv_show              | imdb_score |
# +----------------------------------+------------+
# |            Chernobyl             |    9.4     |
# |         Band of Brothers         |    9.4     |
# |             The Wire             |    9.3     |
# |              Lamput              |    9.3     |
# |        Eyes on the Prize         |    9.2     |
# |          Rick and Morty          |    9.2     |
# |           The Sopranos           |    9.2     |
# |         Game of Thrones          |    9.2     |
# | Fullmetal Alchemist: Brotherhood |    9.1     |
# |         Hunter x Hunter          |    9.0     |
# +----------------------------------+------------+

# %% [markdown]
# ####  Selected the top 10 tv shows by tmdb popularity that were released in the 21st century

# %%
# %%sql SELECT title as tv_show, ROUND(CAST(tmdb_popularity AS DECIMAL),2) as tmdb_popularity
# FROM Public."Titles"
# WHERE seasons is NULL
# AND tmdb_popularity IS NOT NULL
# AND release_year BETWEEN 2000 AND 2022
# ORDER BY tmdb_popularity DESC
# LIMIT 10;
# Out:
# Running query in 'postgresql://postgres:***@localhost:5433/HBO_TV_Movies'
# 10 rows affected.
# +--------------------------+-----------------+
# |         tv_show          | tmdb_popularity |
# +--------------------------+-----------------+
# |        The Batman        |     4447.89     |
# | The Matrix Resurrections |      641.54     |
# |           Kimi           |      565.89     |
# |      The King's Man      |      559.09     |
# |         Free Guy         |      398.52     |
# |    Death on the Nile     |      386.01     |
# |      Mortal Kombat       |      366.71     |
# |    The Suicide Squad     |      345.90     |
# |     Nightmare Alley      |      342.80     |
# |         Antlers          |      315.57     |
# +--------------------------+-----------------+

# %% [markdown]
# #### Selected the top 10 tv shows by tmdb score

# %%
# %%sql SELECT title as tv_show, tmdb_score
# FROM Public."Titles"
# WHERE seasons IS NOT NULL
# AND tmdb_score IS NOT NULL
# AND tmdb_score = 10.0
# ORDER BY tmdb_score DESC
# LIMIT 10;
# Out:
# Running query in 'postgresql://postgres:***@localhost:5433/HBO_TV_Movies'
# 10 rows affected.
# +----------------------------------+------------+
# |             tv_show              | tmdb_score |
# +----------------------------------+------------+
# |          Tom and Jerry           |    10.0    |
# |             Autopsy              |    10.0    |
# |             Crashbox             |    10.0    |
# | Category 7: The End of the World |    10.0    |
# |          Classical Baby          |    10.0    |
# |         Little Baby Bum          |    10.0    |
# |            Dios Inc.             |    10.0    |
# |       Secret Life of Lakes       |    10.0    |
# |     Secret Life Underground      |    10.0    |
# |       The History of Food        |    10.0    |
# +----------------------------------+------------+

# %% [markdown]
# #### Selected the top 10 tv shows by the most imdb votes

# %%
# %%sql SELECT title as tv_show, ROUND(MAX(imdb_votes)) as highest_votes
# FROM Public."Titles"
# WHERE seasons IS NOT NULL
# GROUP BY tv_show
# HAVING MAX(imdb_votes) IS NOT NULL
# ORDER BY highest_votes DESC
# LIMIT 10;
# Out:
# Running query in 'postgresql://postgres:***@localhost:5433/HBO_TV_Movies'
# 10 rows affected.
# +---------------------+---------------+
# |       tv_show       | highest_votes |
# +---------------------+---------------+
# |   Game of Thrones   |    1983794    |
# |       Friends       |     950362    |
# | The Big Bang Theory |     782154    |
# |      Chernobyl      |     693955    |
# |    True Detective   |     546443    |
# |      Westworld      |     474807    |
# |    Rick and Morty   |     473951    |
# |   Band of Brothers  |     440706    |
# |     The Sopranos    |     372367    |
# |      South Park     |     359621    |
# +---------------------+---------------+

# %% [markdown]
# #### Wrote a query to determine the  number of directors who directed movies that received an imdb score of 9.0 or higher

# %%
# %%sql SELECT role, name, title AS movie, imdb_score
# FROM Public."Credits"
# INNER JOIN Public."Titles"
# ON Public."Credits".id = Public."Titles".id
# WHERE imdb_score IS NOT NULL
# AND role = 'DIRECTOR'
# AND seasons IS NULL
# AND imdb_score IS NOT NULL
# AND imdb_score >= 9.0
# ORDER BY 4 DESC
# Out:
# Running query in 'postgresql://postgres:***@localhost:5433/HBO_TV_Movies'
# 4 rows affected.
# +----------+---------------------+-----------------------------------------------+------------+
# |   role   |         name        |                     movie                     | imdb_score |
# +----------+---------------------+-----------------------------------------------+------------+
# | DIRECTOR |    Frank Darabont   |            The Shawshank Redemption           |    9.3     |
# | DIRECTOR |  Christopher Nolan  |                The Dark Knight                |    9.0     |
# | DIRECTOR |    Peter Jackson    | The Lord of the Rings: The Return of the King |    9.0     |
# | DIRECTOR | Jean Gabriel Guerra |  Juan Luis Guerra 4.40: Entre Mar y Palmeras  |    9.0     |
# +----------+---------------------+-----------------------------------------------+------------+

# %% [markdown]
# #### Selected the top 10 movies by tmdb score

# %%
# %%sql SELECT title as movie, tmdb_score
# FROM Public."Titles"
# WHERE seasons IS NULL
# AND tmdb_score IS NOT NULL
# ORDER BY tmdb_score DESC
# LIMIT 10;
# Out:
# Running query in 'postgresql://postgres:***@localhost:5433/HBO_TV_Movies'
# 10 rows affected.
# +------------------------------------------------------------+------------+
# |                           movie                            | tmdb_score |
# +------------------------------------------------------------+------------+
# |                     A Storybook Ending                     |    10.0    |
# |          Shakira in Concert: El Dorado World Tour          |    10.0    |
# |                          Netizens                          |    10.0    |
# | Santana: Corazón Live from Mexico  - Live It To Believe It |    10.0    |
# |            Euphoria: Trouble Don't Last Always             |    10.0    |
# |             Mike Mulligan and His Steam Shovel             |    10.0    |
# |                   American Revolution 2                    |    10.0    |
# |          Goodnight Moon & Other Sleepytime Tales           |    10.0    |
# ...

# %% [markdown]
# #### Selected the top 10 movies by imdb score

# %%
# %%sql SELECT title as movie, imdb_score
# FROM Public."Titles"
# WHERE seasons IS NULL
# AND imdb_score IS NOT NULL
# ORDER BY imdb_score DESC
# LIMIT 10;
# Out:
# Running query in 'postgresql://postgres:***@localhost:5433/HBO_TV_Movies'
# 10 rows affected.
# +---------------------------------------------------+------------+
# |                       movie                       | imdb_score |
# +---------------------------------------------------+------------+
# |              The Shawshank Redemption             |    9.3     |
# |                 Emergency Contact                 |    9.2     |
# |        Euphoria: Trouble Don't Last Always        |    9.0     |
# |   The Lord of the Rings: The Return of the King   |    9.0     |
# |    Juan Luis Guerra 4.40: Entre Mar y Palmeras    |    9.0     |
# |                  The Dark Knight                  |    9.0     |
# |                     Inception                     |    8.8     |
# | The Lord of the Rings: The Fellowship of the Ring |    8.8     |
# |        Dave Chappelle: Killin' Them Softly        |    8.8     |
# |       The Lord of the Rings: The Two Towers       |    8.8     |
# ...

# %% [markdown]
# #### Selected the top 10 movies by the most imdb votes

# %%
# %%sql SELECT title as movie, ROUND(MAX(imdb_votes)) as highest_votes
# FROM Public."Titles"
# WHERE seasons IS NULL
# GROUP BY title
# HAVING MAX(imdb_votes) IS NOT NULL
# ORDER BY highest_votes DESC
# LIMIT 10;
# Out:
# Running query in 'postgresql://postgres:***@localhost:5433/HBO_TV_Movies'
# 10 rows affected.
# +---------------------------------------------------+---------------+
# |                       movie                       | highest_votes |
# +---------------------------------------------------+---------------+
# |                  The Dark Knight                  |    2555504    |
# |              The Shawshank Redemption             |    2548100    |
# |                     Inception                     |    2268288    |
# |                     The Matrix                    |    1857949    |
# | The Lord of the Rings: The Fellowship of the Ring |    1798012    |
# |   The Lord of the Rings: The Return of the King   |    1776725    |
# |       The Lord of the Rings: The Two Towers       |    1604677    |
# |                       Se7en                       |    1586065    |
# |                   Batman Begins                   |    1426616    |
# ...
